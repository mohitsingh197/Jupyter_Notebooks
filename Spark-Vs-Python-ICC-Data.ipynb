# %%
import numpy as np
import pandas as pd

# %%
import sys
import types

from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_9fa254825cf748af8c99d9684609cb33 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='pGtcK4Cfe0bYhkzj57xpd52SoW35u9AminIgvd2fgQxN',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_9fa254825cf748af8c99d9684609cb33.get_object(Bucket='sparkscalapythonplayground-donotdelete-pr-pmmafeibz2hwiv',Key='ODIs - Batting.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

odi_bat = pd.read_csv(body)

body = client_9fa254825cf748af8c99d9684609cb33.get_object(Bucket='sparkscalapythonplayground-donotdelete-pr-pmmafeibz2hwiv',Key='ODIs - All Round.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

odi_all_around = pd.read_csv(body)

body = client_9fa254825cf748af8c99d9684609cb33.get_object(Bucket='sparkscalapythonplayground-donotdelete-pr-pmmafeibz2hwiv',Key='ODIs - Data as at.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

odi_data_as_at = pd.read_csv(body)

body = client_9fa254825cf748af8c99d9684609cb33.get_object(Bucket='sparkscalapythonplayground-donotdelete-pr-pmmafeibz2hwiv',Key='ODIs - Teams Batting.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

odi_teams_batting = pd.read_csv(body)

body = client_9fa254825cf748af8c99d9684609cb33.get_object(Bucket='sparkscalapythonplayground-donotdelete-pr-pmmafeibz2hwiv',Key='ODIs - Partnerships.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

odi_partnerships = pd.read_csv(body)

# %%
odi_bat.head()
# Out:
#                        Player Career Span  Career Start  Career End  \
# 0         IR Bell (2004-2015)   2004-2015          2004        2015
# 1      EJG Morgan (2009-2018)   2009-2018          2009        2018
# 2  PD Collingwood (2001-2011)   2001-2011          2001        2011
# 3      AJ Stewart (1989-2003)   1989-2003          1989        2003
# 4         JE Root (2013-2018)   2013-2018          2013        2018
#
#    Matches Played Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 0             161            157       14        5416                   141
# 1             177            164       23        5287                  124*
# 2             197            181       37        5092                  120*
# 3             170            162       14        4677                   116
# 4             107            101       14        4451                  133*
#
#   Highest Innings Score Num           ...            Balls Faced  \
# ...

# %%
odi_all_around.head()
# Out:
#                        Player  Batting-Bowling Avg Diff  All-Round Ind
# 0      A Flintoff (1999-2009)                      8.35              1
# 1  PD Collingwood (2001-2011)                     -3.32              1
# 2       IT Botham (1976-1992)                     -5.32              1
# 3       SR Watson (2002-2015)                      8.74              1
# 4       A Symonds (1998-2009)                      2.49              1

# %%
odi_data_as_at.head()
# Out:
#   Statsguru includes the following current or recent One-Day Internationals:
# 0  Afghanistan v West Indies at Harare, ICC Crick...
# 1  Afghanistan v Ireland at Harare, ICC Cricket W...
# 2  Zimbabwe v United Arab Emirates at Harare, ICC...

# %%
odi_teams_batting.head()
# Out:
#         Country  Team Matches Played  Matches Won  Matches Lost  Matches Tied  \
# 0       England                  707          350           325             8
# 1     Australia                  911          556           312             9
# 2  South Africa                  589          362           205             6
# 3   West Indies                  777          385           356             9
# 4   New Zealand                  744          334           365             6
#
#    Matches With No Result  Win/Loss Ratio  Avg Runs Per Wicket Batting  \
# 0                      24           1.076                        30.59
# 1                      34           1.782                        34.10
# 2                      16           1.765                        35.56
# 3                      27           1.081                        29.96
# 4                      39           0.915                        28.99
#
#    Avg Runs Per Six Balls Batting  Number Of Team Innings Batting  \
# ...

# %%
odi_partnerships.head()
# Out:
#                      Partners Partnership Career Span  \
# 0            IR Bell, AN Cook               2006-2014
# 1         EJG Morgan, JE Root               2013-2018
# 2           AD Hales, JE Root               2014-2018
# 3   NV Knight, ME Trescothick               2001-2003
# 4  PD Collingwood, A Flintoff               2001-2009
#
#    Partnership Career Start  Partnership Career End  Number Of Partnerships  \
# 0                      2006                    2014                      54
# 1                      2013                    2018                      56
# 2                      2014                    2018                      27
# 3                      2001                    2003                      46
# 4                      2001                    2009                      43
#
#    Unbroken Partnerships  Total Partnership Runs Highest Partnership  \
# 0                      2                    2118                 178
# ...

# %%
odi_bat['Runs Scored'] = odi_bat[odi_bat['Runs Scored'] != '-']['Runs Scored'].astype(str).astype(np.int32)

# %%
odi_bat.loc[odi_bat['Runs Scored'].idxmax()]
# Out:
# Player                       SR Tendulkar (1989-2012)
# Career Span                                 1989-2012
# Career Start                                     1989
# Career End                                       2012
# Matches Played                                    463
# Innings Batted                                    452
# Not Outs                                           41
# Runs Scored                                     18426
# Highest Innings Score                            200*
# Highest Innings Score Num                         200
# Batting Avg                                     44.83
# Balls Faced                                     21367
# Batting Strike Rate                             86.23
# Hundreds Scored                                    49
# Scores Of Fifty Or More                            96
# Ducks Scored                                       20
# Country                                         India
# ...

# %%
odi_bat['Hundreds Scored'] = odi_bat[odi_bat['Hundreds Scored'] != '-']['Hundreds Scored'].astype(np.int16)

# %%
display(odi_bat['Hundreds Scored'].loc[950:1050].plot())

# %%
odi_bat['Hundreds Scored']

# %%
odi_partnerships.loc[odi_partnerships['Total Partnership Runs'].idxmax(),:]
# Out:
# Partners                            SC Ganguly, SR Tendulkar
# Partnership Career Span                            1992-2007
# Partnership Career Start                                1992
# Partnership Career End                                  2007
# Number Of Partnerships                                   176
# Unbroken Partnerships                                      3
# Total Partnership Runs                                  8227
# Highest Partnership                                      258
# Avg Partnership Per Dismissal                          47.55
# Century Partnerships                                      26
# Fifty Runs And Over Partnerships                          29
# Country                                                India
# Name: 6465, dtype: object

# %%
odi_partnerships.loc[odi_partnerships['Unbroken Partnerships'].idxmax(),:]
# Out:
# Partners                            AB de Villiers, JP Duminy
# Partnership Career Span                             2007-2017
# Partnership Career Start                                 2007
# Partnership Career End                                   2017
# Number Of Partnerships                                     61
# Unbroken Partnerships                                      13
# Total Partnership Runs                                   2658
# Highest Partnership                                       219
# Avg Partnership Per Dismissal                           55.37
# Century Partnerships                                        7
# Fifty Runs And Over Partnerships                           16
# Country                                          South Africa
# Name: 3044, dtype: object

# %%
odi_partnerships['Avg Partnership Per Dismissal'] = odi_partnerships[odi_partnerships['Avg Partnership Per Dismissal'] != "-"]['Avg Partnership Per Dismissal'].astype('float32')

# %%
odi_partnerships.loc[odi_partnerships[odi_partnerships['Number Of Partnerships'] > 10]['Avg Partnership Per Dismissal'].idxmax(),:]
# Out:
# Partners                            JH Kallis, JA Rudolph
# Partnership Career Span                         2003-2004
# Partnership Career Start                             2003
# Partnership Career End                               2004
# Number Of Partnerships                                 12
# Unbroken Partnerships                                   2
# Total Partnership Runs                                790
# Highest Partnership                                  162*
# Avg Partnership Per Dismissal                          79
# Century Partnerships                                    3
# Fifty Runs And Over Partnerships                        3
# Country                                      South Africa
# Name: 3078, dtype: object

# %%
odi_partnerships.loc[odi_partnerships[odi_partnerships['Number Of Partnerships'] >= 30]['Avg Partnership Per Dismissal'].sort_values(ascending=False).index[:10]]
# Out:
#                         Partners Partnership Career Span  \
# 3042     HM Amla, AB de Villiers               2008-2018
# 6476           S Dhawan, V Kohli               2011-2018
# 6470          V Kohli, RG Sharma               2010-2018
# 6481          G Gambhir, V Kohli               2008-2013
# 1643       RT Ponting, SR Watson               2006-2011
# 6469          MS Dhoni, SK Raina               2005-2015
# 6479           V Kohli, SK Raina               2008-2015
# 6484          V Kohli, AM Rahane               2011-2018
# 6480      A Jadeja, SR Tendulkar               1992-2000
# 5189  LRPL Taylor, KS Williamson               2010-2018
#
#       Partnership Career Start  Partnership Career End  \
# 3042                      2008                    2018
# 6476                      2011                    2018
# 6470                      2010                    2018
# 6481                      2008                    2013
# 1643                      2006                    2011
# ...

# %%
odi_bat[odi_bat['Player'].str.contains('Rudolph')]
# Out:
#                      Player Career Span  Career Start  Career End  \
# 496  JA Rudolph (2003-2006)   2003-2006          2003        2006
#
#      Matches Played Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 496              43             37        6        1157                    81
#
#     Highest Innings Score Num           ...            Balls Faced  \
# 496                        81           ...                   1685
#
#     Batting Strike Rate Hundreds Scored Scores Of Fifty Or More Ducks Scored  \
# 496               68.66               0                       7            0
#
#           Country Player Count  5000+ Runs Scored  40+ Batting Avg  \
# 496  South Africa            1                  0                0
#
#      90+ Batting Strike Rate
# 496                        0
#
# [1 rows x 21 columns]

# %%
odi_partnerships[odi_partnerships['Partners'].str.contains('Dhoni')]
# Out:
#                        Partners Partnership Career Span  \
# 6469         MS Dhoni, SK Raina               2005-2015
# 6473     MS Dhoni, Yuvraj Singh               2005-2017
# 6489          MS Dhoni, V Kohli               2008-2018
# 6492        MS Dhoni, RA Jadeja               2009-2017
# 6493         MS Dhoni, R Dravid               2005-2009
# 6494        MS Dhoni, G Gambhir               2005-2012
# 6497        MS Dhoni, RG Sharma               2008-2017
# 6516     MS Dhoni, SR Tendulkar               2005-2012
# 6526         MS Dhoni, V Sehwag               2005-2010
# 6546         R Ashwin, MS Dhoni               2011-2015
# 6563        MS Dhoni, IK Pathan               2005-2012
# 6570           MS Dhoni, M Kaif               2004-2006
# 6581       MS Dhoni, KD Karthik               2006-2017
# 6585          MS Dhoni, B Kumar               2013-2018
# 6590        MS Dhoni, KM Jadhav               2016-2017
# 6598       MS Dhoni, RV Uthappa               2007-2008
# ...

# %%
import ibmos2spark

# @hidden_cell
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'api_key': 'pGtcK4Cfe0bYhkzj57xpd52SoW35u9AminIgvd2fgQxN',
    'service_id': 'iam-ServiceId-8270013a-9afb-4c42-9b56-f62850a9c0f4',
    'iam_service_endpoint': 'https://iam.ng.bluemix.net/oidc/token'}

configuration_name = 'os_9fa254825cf748af8c99d9684609cb33_configs'
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
df_batting = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('ODIs - Batting.csv', 'sparkscalapythonplayground-donotdelete-pr-pmmafeibz2hwiv'))

# %%
df_batting.take(1)
# Out:
# [Row(Player='IR Bell (2004-2015)', Career Span='2004-2015', Career Start='2004', Career End='2015', Matches Played='161', Innings Batted='157', Not Outs='14', Runs Scored='5416', Highest Innings Score='141', Highest Innings Score Num='141', Batting Avg='37.87', Balls Faced='7019', Batting Strike Rate='77.16', Hundreds Scored='4', Scores Of Fifty Or More='35', Ducks Scored='6', Country='England', Player Count='1', 5000+ Runs Scored='1', 40+ Batting Avg='0', 90+ Batting Strike Rate='0')]

# %%
from pyspark.sql import functions as F

# %%
df_batting = df_batting.withColumn('Runs Scored', F.col('Runs Scored').cast('int'))
df_batting.take(1)
# Out:
# [Row(Player='IR Bell (2004-2015)', Career Span='2004-2015', Career Start='2004', Career End='2015', Matches Played='161', Innings Batted='157', Not Outs='14', Runs Scored=5416, Highest Innings Score='141', Highest Innings Score Num='141', Batting Avg='37.87', Balls Faced='7019', Batting Strike Rate='77.16', Hundreds Scored='4', Scores Of Fifty Or More='35', Ducks Scored='6', Country='England', Player Count='1', 5000+ Runs Scored='1', 40+ Batting Avg='0', 90+ Batting Strike Rate='0')]

# %%
df_batting.withColumn('tempid', F.lit(0)).select('*').groupBy('tempid').agg(F.max('Runs Scored')).show()
# Out:
# +------+----------------+
# |tempid|max(Runs Scored)|
# +------+----------------+
# |     0|           18426|
# +------+----------------+

# %%
odi_bat['Runs Scored'].dtype
# Out:
# dtype('float64')

# %%
odi_bat[odi_bat['Runs Scored'] > 10000][['Player','Runs Scored']].set_index('Player').sort_values('Runs Scored', ascending=False)
# Out:
#                               Runs Scored
# Player
# SR Tendulkar (1989-2012)          18426.0
# KC Sangakkara (2000-2015)         13975.0
# RT Ponting (1995-2012)            13589.0
# ST Jayasuriya (1989-2011)         13364.0
# DPMD Jayawardene (1998-2015)      12381.0
# Inzamam-ul-Haq (1991-2007)        11701.0
# JH Kallis (1996-2014)             11550.0
# SC Ganguly (1992-2007)            11221.0
# R Dravid (1996-2011)              10768.0
# BC Lara (1990-2007)               10348.0
# TM Dilshan (1999-2016)            10290.0

# %%
display(odi_bat[odi_bat['Runs Scored'] > 10000][['Player','Runs Scored']].set_index('Player').plot(type='hist'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-49fec602681a> in <module>()
# ----> 1 display(odi_bat[odi_bat['Runs Scored'] > 10000][['Player','Runs Scored']].set_index('Player').plot(type='hist'))
#
# ~/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# ...

# %%
odi_bat['Hundreds Scored'] = odi_bat[odi_bat['Hundreds Scored'] != '-']['Hundreds Scored'].astype('int16')

# %%
odi_bat[['Country', 'Hundreds Scored']].groupby('Country').sum().sort_values('Hundreds Scored', ascending=False)
# Out:
#               Hundreds Scored
# Country
# India                   265.0
# Australia               211.0
# Pakistan                185.0
# South Africa            173.0
# Sri Lanka               169.0
# West Indies             166.0
# England                 156.0
# New Zealand             125.0
# Zimbabwe                 61.0
# Bangladesh               42.0
# Ireland                  32.0
# Afghanistan              15.0

# %%
df_batting = df_batting.withColumn('Hundreds Scored', F.col('Hundreds Scored').cast('int'))

# %%
df_batting.groupBy('Country').agg(F.sum('Hundreds Scored').alias('Total Hundreds Scored')).sort('Total Hundreds Scored', ascending=False).show()
# Out:
# +------------+---------------------+
# |     Country|Total Hundreds Scored|
# +------------+---------------------+
# |       India|                  265|
# |   Australia|                  211|
# |    Pakistan|                  185|
# |South Africa|                  173|
# |   Sri Lanka|                  169|
# | West Indies|                  166|
# |     England|                  156|
# | New Zealand|                  125|
# |    Zimbabwe|                   61|
# |  Bangladesh|                   42|
# |     Ireland|                   32|
# | Afghanistan|                   15|
# +------------+---------------------+
